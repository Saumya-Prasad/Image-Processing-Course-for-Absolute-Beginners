# %% [markdown]
# # I058 Saumya Prasad SIP Lab Exp 3
# ### Date: 28th January 2025
# ### BTech AI - Batch B3

# %%
import cv2
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
from numpy import *

# %% [markdown]
# ## Question 1 - Reading an Image using CV2

# %%
img = cv2.imread(r"C:\Users\mpstme.student\Downloads\Cameraman.png")
plt.imshow(img)

# %% [markdown]
# ## Question 2 - Display Image using mathplotlib

# %%
plt.imshow(img, cmap = 'gray')
plt.title('Original Image')
plt.show()

# %% [markdown]
# ## Question 3 - Negative Image

# %%
n = (2**8-1)-img
plt.imshow(n, cmap = 'gray')
plt.title('Negative Image')
plt.show()

# %% [markdown]
# ## Question 4 - Thresholding Image

# %%
#Threshold value as 50
threshold = int(input("Enter in a threshold value to obtain thresholding of an image: "))
s = np.where(img>threshold,0,255)
plt.imshow(s, cmap = 'gray')
plt.title("Thresholding Image")
plt.show()
# Out:
# Enter in a threshold value to obtain thresholding of an image: 50

# %%
#Threshold value as 130
threshold = int(input("Enter in a threshold value to obtain thresholding of an image: "))
s1 = np.where(img>threshold,0,255)
plt.imshow(s1, cmap = 'gray')
plt.title("Thresholding Image")
plt.show()
# Out:
# Enter in a threshold value to obtain thresholding of an image: 130

# %%
#Threshold value as 180
threshold = int(input("Enter in a threshold value to obtain thresholding of an image: "))
s2 = np.where(img>threshold,0,255)
plt.imshow(s2, cmap = 'gray')
plt.title("Thresholding Image")
plt.show()
# Out:
# Enter in a threshold value to obtain thresholding of an image: 180

# %% [markdown]
# ## Question 5 - Image Without Background

# %%
# Image Without Background with value as a=70 ans b=150
a = int(input("Enter in a range a: "))
b = int(input("Enter in a range b: "))
al = img > a
bl = img < b
q = np.where(al & bl, 0,255)
plt.imshow(q, cmap = 'gray')
plt.title("Image Without Background")
plt.show()
# Out:
# Enter in a range a: 70
# Enter in a range b: 150

# %%
# Image Without Background with value as a=30 ans b=100
a = int(input("Enter in a range a: "))
b = int(input("Enter in a range b: "))
al = img > a
bl = img < b
q2 = np.where(al & bl, 0,255)
plt.imshow(q2, cmap = 'gray')
plt.title("Image Without Background")
plt.show()
# Out:
# Enter in a range a: 30
# Enter in a range b: 100

# %%
# Image Without Background with value as a=10 ans b=100
a = int(input("Enter in a range a: "))
b = int(input("Enter in a range b: "))
al = img > a
bl = img < b
q3 = np.where(al & bl, 0,255)
plt.imshow(q3, cmap = 'gray')
plt.title("Image Without Background")
plt.show()
# Out:
# Enter in a range a: 10
# Enter in a range b: 100

# %%
# Image Without Background with value as a=1 ans b=50
a = int(input("Enter in a range a: "))
b = int(input("Enter in a range b: "))
al = img > a
bl = img < b
q4 = np.where(al & bl, 0,255)
plt.imshow(q4, cmap = 'gray')
plt.title("Image Without Background")
plt.show()
# Out:
# Enter in a range a: 1
# Enter in a range b: 50

# %% [markdown]
# ## Question 6 - Image Without Foreground

# %%
# Image Without Foreground with value as a=70 ans b=200
a = int(input("Enter in a range a: "))
b = int(input("Enter in a range b: "))
al = img > a
bl = img < b
r = np.where(al & bl, img,255)
plt.imshow(r, cmap = 'gray')
plt.title("Image Without Foreground")
plt.show()
# Out:
# Enter in a range a: 70
# Enter in a range b: 200

# %%
# Image Without Foreground with value as a=50 ans b=200
a = int(input("Enter in a range a: "))
b = int(input("Enter in a range b: "))
al = img > a
bl = img < b
r1 = np.where(al & bl, img,255)
plt.imshow(r1, cmap = 'gray')
plt.title("Image Without Foreground")
plt.show()
# Out:
# Enter in a range a: 50
# Enter in a range b: 200

# %% [markdown]
# # Question 7 - Plot All Image

# %%
plt.figure(figsize=(8,7))
plt.subplot(2,2,1)
plt.title('Negative Image')
plt.imshow(n, cmap = 'gray')

plt.subplot(2,2,2)
plt.title('Thresholding Image')
plt.imshow(s1, cmap = 'gray')

plt.subplot(2,2,3)
plt.title('Image Without Background')
plt.imshow(q3, cmap = 'gray')

plt.subplot(2,2,4)
plt.title('Image Without Foreground')
plt.imshow(r, cmap = 'gray')
